# %%
df.describe()
# Out:
#        Average Rent (INR/month)  Food Cost (INR/month)  Internet Speed (Mbps)  \
# count                170.000000             170.000000             170.000000
# mean                8022.052941            5439.329412              87.487176
# std                 4839.775925            1433.162559              34.260658
# min                 4009.000000            3021.000000              20.350000
# 25%                 5490.750000            4320.000000              59.200000
# 50%                 6966.000000            5388.500000              91.640000
# 75%                 8599.750000            6709.500000             113.822500
# max                34896.000000            7999.000000             149.460000
#
#        Healthcare Rating  Safety Score  Happiness Index
# count         170.000000    170.000000       170.000000
# mean            6.451765      5.493529         6.427647
# std             1.506759      2.085740         1.272141
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# City                        0
# Average Rent (INR/month)    0
# Food Cost (INR/month)       0
# Internet Speed (Mbps)       0
# Healthcare Rating           0
# Safety Score                0
# Happiness Index             0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 170 entries, 0 to 169
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   City                      170 non-null    str
#  1   Average Rent (INR/month)  170 non-null    int64
#  2   Food Cost (INR/month)     170 non-null    int64
#  3   Internet Speed (Mbps)     170 non-null    float64
#  4   Healthcare Rating         170 non-null    float64
#  5   Safety Score              170 non-null    float64
#  6   Happiness Index           170 non-null    float64
# dtypes: float64(4), int64(2), str(1)
# memory usage: 9.4 KB

# %%
df.shape
# Out:
# (170, 7)

# %%
df.columns.to_list()
# Out:
# ['City',
#  'Average Rent (INR/month)',
#  'Food Cost (INR/month)',
#  'Internet Speed (Mbps)',
#  'Healthcare Rating',
#  'Safety Score',
#  'Happiness Index']

# %%
import pandas as pd;
df = pd.read_csv("../data/raw/india_cost_quality_dataset.csv")
df.head()
# Out:
#         City  Average Rent (INR/month)  Food Cost (INR/month)  \
# 0     Mumbai                     34896                   6196
# 1      Delhi                     26424                   4487
# 2  Bengaluru                     26667                   6936
# 3  Hyderabad                     25785                   6375
# 4  Ahmedabad                     20881                   3632
#
#    Internet Speed (Mbps)  Healthcare Rating  Safety Score  Happiness Index
# 0                  94.48                6.2           2.7              5.3
# 1                 130.26                6.1           2.6              5.6
# 2                  81.36                8.7           6.7              7.5
# 3                 108.84                7.8           7.7              6.3
# 4                 130.80                5.5           7.9              4.3
